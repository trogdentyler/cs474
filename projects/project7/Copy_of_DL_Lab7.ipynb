# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances. Think about what each dimension means to find out which dimensions you'll want to perform each operation on.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clones()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
# !pip install torch==1.9.0

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext==0.10.0
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.4/831.4 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0) (4.5.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# Successfully installed torch-1.9.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.10.0
#   Downloading torchtext-0.10.0-cp38-cp38-manylinux1_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 75.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (2.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (1.22.4)
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.8/dist-packages (from torchtext==0.10.0) (1.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.9.0->torchtext==0.10.0) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.10.0) (1.26.14)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.14.1
#     Uninstalling torchtext-0.14.1:
#       Successfully uninstalled torchtext-0.14.1
# Successfully installed torchtext-0.10.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (23.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.1.2)
# 2023-03-02 20:14:01.689177: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-02 20:14:04.734435: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-02 20:14:04.734755: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-02 20:14:04.734779: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.22.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.25.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.0.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2023-03-02 20:14:20.424656: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-02 20:14:21.692202: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-02 20:14:21.692337: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-02 20:14:21.692363: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.4.0/es_core_news_sm-3.4.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 93.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from es-core-news-sm==3.4.0) (3.4.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (6.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.22.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (57.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.4.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.25.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# --2023-03-02 20:14:30--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.04s
#
# 2023-03-02 20:14:31 (222 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2023-03-02 20:14:31--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.04s
#
# 2023-03-02 20:14:31 (182 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        # print("x size: ", x.size())
        # print("other size: ", self.dropout(sublayer(self.norm(x))).size())
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ## Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'
    _, _, d_k = query.size()

    # scores = QK^T/scale
    scale = 1. / (d_k **.5)
    scores = torch.matmul(query * scale, key.transpose(1, 2))

    # print("Scores size: ", scores.size())
    # print("Mask: ", mask is not None, "\n")

    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    # print("Scores size: ", scores.size())

    # print("Value size: ", value.size())
    # print("Soft size: ", F.softmax(scores, dim=2).size())

    scores = F.softmax(scores, dim=2)
    output = torch.matmul(scores, value)
    
    # print("Output: ", output.size(), "\n")
    
    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        # Implement Multi-head attention mechanism
        self.h = h

        assert d_model % h == 0

        d_k = d_model // h
        d_v = d_model // h
        # print(d_k, d_v)

        # Make an attention head (linear layers for q, k, and v)
        self.W_q = nn.Linear(in_features=d_model, out_features=d_k, bias=False)
        self.W_k = nn.Linear(in_features=d_model, out_features=d_k, bias=False)
        self.W_v = nn.Linear(in_features=d_model, out_features=d_v, bias=False)
        # print("In features size: ", h * d_v)
        # print("Out features size: ", d_model)
        self.W_out = nn.Linear(in_features=h * d_v, out_features=d_model, bias=False)
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=.1)
        
        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.Q_heads = clones(self.W_q, h)
        self.K_heads = clones(self.W_k, h)
        self.V_heads = clones(self.W_v, h)
        
    def forward(self, query, key, value, mask):
      heads = []
      for i in range(self.h):
        head = attention(self.Q_heads[i](query),\
                         self.K_heads[i](key),\
                         self.V_heads[i](value), mask)
        
        # print("Head size: ", head.size())
        heads.append(head)

      # print("Concated size: ", torch.cat(heads).size())
      heads = torch.cat(heads, dim=2)
      heads = self.W_out(heads)

      return self.dropout(heads)

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es_core_news_sm')
spacy_en = spacy.load('en_core_web_sm')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
with open('./spanish', 'r', encoding='utf-8') as spanish_text:
  spanish_lines = list(spanish_text)
with open('./english', 'r', encoding='utf-8') as english_text:
  english_lines = list(english_text)

fields = (["src", SRC], ["trg", TGT])
examples = [data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ## Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 5
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        run_epoch((rebatch(pad_idx, b) for b in train_iter), 
                  model, 
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# Epoch Step: 1 Loss: 8.669130 Tokens per Sec: 3954.453857
# Epoch Step: 51 Loss: 5.515281 Tokens per Sec: 11725.098633
# Epoch Step: 101 Loss: 5.739965 Tokens per Sec: 9417.821289
# Epoch Step: 151 Loss: 5.458116 Tokens per Sec: 11600.006836
# Epoch Step: 201 Loss: 4.967002 Tokens per Sec: 11596.857422
# Epoch Step: 251 Loss: 5.131963 Tokens per Sec: 9405.360352
# Epoch Step: 301 Loss: 4.255430 Tokens per Sec: 11728.010742
# Epoch Step: 351 Loss: 4.778378 Tokens per Sec: 11654.766602
# Epoch Step: 401 Loss: 4.676744 Tokens per Sec: 10727.202148
# Epoch Step: 451 Loss: 4.544282 Tokens per Sec: 10068.652344
# Epoch Step: 501 Loss: 5.064513 Tokens per Sec: 11658.148438
# Epoch Step: 551 Loss: 4.234903 Tokens per Sec: 11704.201172
# Epoch Step: 601 Loss: 4.402346 Tokens per Sec: 9690.164062
# Epoch Step: 651 Loss: 4.276103 Tokens per Sec: 11506.293945
# Epoch Step: 701 Loss: 4.502405 Tokens per Sec: 11759.612305
# Epoch Step: 751 Loss: 4.408368 Tokens per Sec: 9099.304688
# Epoch Step: 801 Loss: 4.204303 Tokens per Sec: 11622.897461
# Epoch Step: 851 Loss: 4.174957 Tokens per Sec: 11841.258789
# Epoch Step: 901 Loss: 4.183984 Tokens per Sec: 9475.659180
# Epoch Step: 951 Loss: 4.680498 Tokens per Sec: 11608.326172
# Epoch Step: 1001 Loss: 4.153940 Tokens per Sec: 11505.522461
# Epoch Step: 1051 Loss: 4.302810 Tokens per Sec: 10113.572266
# Epoch Step: 1101 Loss: 4.282157 Tokens per Sec: 10774.745117
# Epoch Step: 1151 Loss: 4.484992 Tokens per Sec: 11565.484375
# Epoch Step: 1201 Loss: 4.087694 Tokens per Sec: 10982.189453
# Epoch Step: 1251 Loss: 4.000579 Tokens per Sec: 9540.256836
# Epoch Step: 1301 Loss: 3.977652 Tokens per Sec: 11722.694336
# Epoch Step: 1 Loss: 3.843831 Tokens per Sec: 3885.222900
# Epoch Step: 51 Loss: 3.868270 Tokens per Sec: 10854.518555
# Epoch Step: 101 Loss: 3.840228 Tokens per Sec: 9892.425781
# Epoch Step: 151 Loss: 3.811218 Tokens per Sec: 11733.030273
# Epoch Step: 201 Loss: 3.938504 Tokens per Sec: 11607.136719
# Epoch Step: 251 Loss: 4.029642 Tokens per Sec: 9402.313477
# Epoch Step: 301 Loss: 4.282784 Tokens per Sec: 11712.054688
# Epoch Step: 351 Loss: 2.538846 Tokens per Sec: 11565.083008
# Epoch Step: 401 Loss: 1.626336 Tokens per Sec: 11596.113281
# Epoch Step: 451 Loss: 1.882066 Tokens per Sec: 9455.164062
# Epoch Step: 501 Loss: 1.869011 Tokens per Sec: 11748.167969
# Epoch Step: 551 Loss: 1.724237 Tokens per Sec: 11550.177734
# Epoch Step: 601 Loss: 2.125958 Tokens per Sec: 10002.641602
# Epoch Step: 651 Loss: 1.480650 Tokens per Sec: 10663.020508
# Epoch Step: 701 Loss: 1.801136 Tokens per Sec: 11669.194336
# Epoch Step: 751 Loss: 1.718381 Tokens per Sec: 11490.104492
# Epoch Step: 801 Loss: 1.313619 Tokens per Sec: 9851.728516
# Epoch Step: 851 Loss: 2.283407 Tokens per Sec: 11799.325195
# Epoch Step: 901 Loss: 2.424861 Tokens per Sec: 11743.354492
# Epoch Step: 951 Loss: 1.574783 Tokens per Sec: 9008.358398
# Epoch Step: 1001 Loss: 1.492121 Tokens per Sec: 11709.831055
# Epoch Step: 1051 Loss: 1.917270 Tokens per Sec: 11747.892578
# Epoch Step: 1101 Loss: 2.088045 Tokens per Sec: 9101.558594
# Epoch Step: 1151 Loss: 1.599011 Tokens per Sec: 11130.653320
# Epoch Step: 1201 Loss: 2.666173 Tokens per Sec: 11754.003906
# Epoch Step: 1251 Loss: 1.841131 Tokens per Sec: 9222.849609
# Epoch Step: 1301 Loss: 1.249349 Tokens per Sec: 11661.335938

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	<unk> aquí
# Translation:	Ministering Question
# Target:		Let ’s stop right here .
#
# Spanish:	Octubre de 2016
# Translation:	October 2016
# Target:		October 2016
#
# Spanish:	El siguiente paso
# Translation:	The following statistical step
# Target:		Your Next Step
#
# Spanish:	Véase Moisés 1:39 .
# Translation:	See Moses 1:39 .
# Target:		See Moses 1:39 .
#
# Spanish:	Véase Helamán 5:12 .
# Translation:	See Helaman 5:12 .
# Target:		See Helaman 5:12 .
#
# Spanish:	Véase Juan <unk> .
# Translation:	See John 16:33 .
# Target:		See John <unk> .
#
# Spanish:	Él nos ayudará .
# Translation:	He will help us .
# Target:		He will help us .
#
# Spanish:	1 de octubre de 2016
# Translation:	October 2016
# Target:		October 01 , 2016
#
# Spanish:	Véase 3 Nefi 27:5–7 .
# Translation:	See 3 Nephi 31:17–20 .
# Target:		See 3 Nephi 27:5–7 .
#
# Spanish:	Presentado por Brook P. Hales
# Translation:	Presented by Brook P. Hales
# Target:		Presented by Brook P. Hales
#
# Spanish:	Doctrina y Convenios 8:2 .
# Translation:	Doctrine and Covenants 8:2 .
# Target:		Doctrine and Covenants 8:2 .
#
# Spanish:	Jesucristo es nuestro Maestro .
# Translation:	Jesus Christ is our Master .
# Target:		Jesus Christ is our Master .
#
# Spanish:	Sesión del domingo por la mañana
# Translation:	Sunday Morning Session
# Target:		Sunday Morning Session
#
# Spanish:	Por el élder D. Todd Christofferson
# Translation:	By Elder D. Todd Christofferson
# Target:		By Elder D. Todd Christofferson
#
# Spanish:	¿ Cuál es la solución ?
# Translation:	What is the solution ?
# Target:		What Is the <unk> ?
#
# Spanish:	Él es el Buen Pastor .
# Translation:	He is the Good Shepherd .
# Target:		He is the Good Shepherd .
#
# Spanish:	Véase Doctrina y Convenios <unk> .
# Translation:	See Doctrine and Covenants 6:20 .
# Target:		See Doctrine and Covenants <unk> .
#
# Spanish:	Del Quórum de los Doce Apóstoles
# Translation:	Of the Quorum of the Twelve Apostles
# Target:		Of the Quorum of the Twelve Apostles
#
# Spanish:	Estamos bajo convenio de hacerlo .
# Translation:	We are under covenant to do .
# Target:		We are under covenant to do so .
#
# Spanish:	¿ Qué es el arrepentimiento ? :
# Translation:	What is repentance the repentance ?
# Target:		What is repentance ?
#
# Spanish:	¡ Vengan , únanse a nosotros !
# Translation:	Come , Join with Us !
# Target:		Come , Join with Us !
#
# Spanish:	El corazón de los hijos se volverá
# Translation:	The Hearts of the Children
# Target:		The Hearts of the Children Shall Turn
#
# Spanish:	Doctrina y Convenios 20:17 , 19 .
# Translation:	Doctrine and Covenants 59:21 .
# Target:		Doctrine and Covenants 20:17 , 19 .
#
# Spanish:	Estamos <unk> en una labor extraordinaria .
# Translation:	We are wearing a remarkable work .
# Target:		We are enlisted in no ordinary task .
#
# Spanish:	Para ser completamente sincero , no <unk>
# Translation:	To be completely honest , we do n’t miss .
# Target:		To be completely honest , we were n’t listening .
#
# Spanish:	A la espera en el camino a Damasco
# Translation:	To the Way to Damascus
# Target:		Waiting on the Road to Damascus
#
# Spanish:	¡ No está hecha por el hombre !
# Translation:	He was not a man !
# Target:		It is not man - made !
#
# Spanish:	Él es la fuente de todo gozo .
# Translation:	He is the source of joy .
# Target:		He is the source of all joy .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	Él promete bendiciones si obedecemos Sus mandamientos .
# Translation:	He promises blessings if we obey His commandments .
# Target:		He promises blessings if we obey His commandments .
#
# Spanish:	Hacemos el bien a quienes nos ultrajan .
# Translation:	We make good ways we are .
# Target:		We do good to those who despitefully use us .
#
# Spanish:	Las decisiones que tomamos determinan nuestro destino .
# Translation:	The choices we make determine our destiny .
# Target:		May we ever choose the harder right instead of the easier wrong .
#
# Spanish:	Dios en verdad nos conoce y nos ama .
# Translation:	God in truth knows us and loves us .
# Target:		God does know and love us .
#
# Spanish:	Su padre falleció cuando él tenía siete años .
# Translation:	His father died when he was seven years old .
# Target:		His father died when he was seven .
#
# Spanish:	Es aceptar a las personas como realmente son .
# Translation:	It is accepting people as people really are .
# Target:		It is accepting people as they truly are .
#
# Spanish:	También están entrelazados con amor con sus antepasados .
# Translation:	They are also interested in their ancestors with their ancestors .
# Target:		They are also linked in love to ancestors .
#
# Spanish:	Cuando lo hizo , fue sanada de inmediato .
# Translation:	When he did , he was healed .
# Target:		When she did so , she was healed immediately .
#
# Spanish:	Pueden orar cuando el coro vaya a cantar .
# Translation:	You can pray when the choir will sing .
# Target:		You can pray as the choir is about to sing .
#
# Spanish:	“ y te mostraré las obras de mis manos
# Translation:	“ And I will show thee the works of my hands .
# Target:		“ And I will show thee the workmanship of mine hands .
#
# Spanish:	¿ El ser paciente y perdonar cuando está enojado ?
# Translation:	Will we forgive and forgive , when he is patient ?
# Target:		Being patient and forgiving when annoyed ?
#
# Spanish:	4 . Aceptar de buena gana la voluntad del Padre
# Translation:	4 . A Good Shepherd
# Target:		4 . Willingly Accepting the Father ’s Will
#
# Spanish:	¿ Qué bendiciones recibimos al escuchar a nuestros padres ?
# Translation:	What blessings receive as we receive as we listened to our parents ?
# Target:		What blessings come from listening to our parents ?
#
# Spanish:	¿ Adónde vamos después de dejar esta vida ? .
# Translation:	Where do we go after this life ?
# Target:		Where do we go after we leave this life ?
#
# Spanish:	Estos nuevos recursos están disponibles para verse en internet .
# Translation:	These new resources are available to the Internet .
# Target:		These new resources are now available for review online .
#
# Spanish:	Menos conocido es el servicio humanitario de nuestra Iglesia .
# Translation:	They fasted is the service of our Church service .
# Target:		Less well known is our Church ’s global humanitarian service .
#
# Spanish:	Descendió debajo de todo para salvar todas las cosas .
# Translation:	Just below all things to save things .
# Target:		He passed beneath all things that He might save all things .
#
# Spanish:	En Jeremías hay un pasaje que me gusta mucho .
# Translation:	In Jeremiah , there is a scripture that I like much .
# Target:		In the book of Jeremiah we find a scripture that is very dear to my heart .
#
# Spanish:	El élder Aoba con los jóvenes creando una pieza de alfarería
# Translation:	Elder Aoba creating pottery
# Target:		Elder Aoba creating pottery with youth
#
# Spanish:	Así que , en realidad , no tenía otra opción .
# Translation:	So , in reality it was not another choice .
# Target:		So I really did n’t have a choice .
#
# Spanish:	El título en sueco es “ När juldagsmorgon glimmar ” .
# Translation:	The Swedish title is “ shipshape and Bristol Fashion . ”
# Target:		The Swedish title is “ När juldagsmorgon glimmar . ”
#
# Spanish:	Aquellos que hablan con claridad pueden hacer que eso suceda .
# Translation:	Those who speak with clarity can do this .
# Target:		Those who speak with clarity can bring this to pass .
#
# Spanish:	Thomas S. Monson es Su profeta para todo el mundo .
# Translation:	Thomas S. Monson is His prophet for all the world .
# Target:		Thomas S. Monson is His prophet to all the world .
#
# Spanish:	Estamos muy agradecidos por las jóvenes que también prestan servicio .
# Translation:	We are grateful for the youth who are also serving .
# Target:		We are very grateful for the young women who also serve .
#
# Spanish:	En el sagrado y santo nombre de Jesucristo . Amén .
# Translation:	In the sacred name of Jesus Christ , amen .
# Target:		In the sacred and holy name of Jesus Christ , amen .
#
# Spanish:	“ Seguimos edificando templos ” , dijo el presidente Monson .
# Translation:	“ We continue to be temple , ” President Monson said .
# Target:		“ We continue to build temples , ” said President Monson . “
#
# Spanish:	Testifico que Jesucristo es el Hijo viviente del Dios viviente .
# Translation:	I testify that Jesus Christ is the living Son of God .
# Target:		I testify that Jesus Christ is the living Son of the living God .
#
# Spanish:	Las jóvenes se protegieron y alentaron la una a la otra .
# Translation:	Young men and women make a place to make another .
# Target:		Young women guarded and encouraged each other .
#
# Spanish:	Nos reímos juntos a medida que trataba una y otra vez .
# Translation:	We sat together as a few as he was and again .
# Target:		We laughed together as he tried again and again .
#
# Spanish:	¿ Cómo hacemos que los caminos del Señor sean nuestros caminos ?
# Translation:	How do we do the ways of the Lord ’s ways ?
# Target:		How do we make the Lord ’s ways our ways ?
#
# Spanish:	“ a causa de vuestra fe … es completo mi gozo .
# Translation:	“ For your faith … is full of joy .
# Target:		“ Because of your faith … , my joy is full .
#
# Spanish:	El sacerdocio perderá gran poder si se <unk> a las hermanas .
# Translation:	The priesthood will be followed by the sisters of sisters .
# Target:		The priesthood will lose great power if the sisters are neglected .
#
# Spanish:	Yo pienso que ningún asunto nuestro es demasiado pequeño o insignificante .
# Translation:	I think that no matter our own or small , small .
# Target:		I believe that no concern of ours is too small or insignificant .
#
# Spanish:	Luego escucharemos al élder Peter F. Meurs , de los Setenta .
# Translation:	Then we hear the Peter F. Meurs , I hear the Seventy .
# Target:		We will then hear from Elder Peter F. Meurs of the Seventy .
#
# Spanish:	En nuestro hogar no hubo discusiones ni palabras hirientes entre nosotros .
# Translation:	In our home there was no words or words .
# Target:		We have not had arguments in our home or unkind words between us .
#
# Spanish:	¿ Cómo podía haber olvidado los largos meses de intenso sufrimiento ?
# Translation:	How could I have forgotten the long months of suffering suffering ?
# Target:		How could long months of incredible suffering and sorrow ever be gone from his mind ?
#
# Spanish:	Las mujeres de la Iglesia de hoy en día son fuertes y valientes
# Translation:	Women in the Church today are strong and valiant .
# Target:		Women in the Church Today Are Strong and Valiant
#
# Spanish:	Para ustedes y para mí , hagamos que ese día sea hoy .
# Translation:	To you and me to do this day , you do today .
# Target:		For you and me , let that day be today .
#
# Spanish:	Una enseñanza del presidente Thomas S. Monson se aplica a esta circunstancia .
# Translation:	One teaching President Thomas S. Monson applies to this circumstance .
# Target:		A teaching of President Thomas S. Monson applies to this circumstance .
#
# Spanish:	El testimonio es el comienzo y un <unk> para una conversión continua .
# Translation:	Testimony is the beginning and a dramatic change for conversion .
# Target:		Testimony is the beginning of and a prerequisite to continuing conversion .
#
# Spanish:	Nuestra motivación y el deseo sincero son semejantes a los del Salvador .
# Translation:	Our motivation and a sincere desire to love the Savior ’s Savior .
# Target:		Our motivation and heartfelt desire are like unto that of the Savior .
#
# Spanish:	Era la única mujer que cavaba alcantarillas entre un grupo de hombres .
# Translation:	It was the only woman who maintained a group of men .
# Target:		She was the only woman digging sewers in a gang of men .
#
# Spanish:	Se propone que sostengamos a <unk> H. <unk> como Setenta de Área .
# Translation:	It is proposed that we sustain Rosemary M. Wixom as Area Seventy .
# Target:		It is proposed that we sustain <unk> H. <unk> as an Area Seventy .
#
# Spanish:	¿ Haremos lo mismo al afrontar los desafíos que se nos presentarán ?
# Translation:	Will we do the same way we face the challenges we will be made ?
# Target:		Will we do likewise as we face those challenges which will be ours ?
#
# Spanish:	Éste es mi testimonio a ustedes . En el nombre de Jesucristo .
# Translation:	This is my testimony to you . In the name of Jesus Christ .
# Target:		This is my witness to you in the name of Jesus Christ , amen .
#
# Spanish:	De joven trabajaba en la fábrica de mi padre durante las vacaciones .
# Translation:	Of the young man ’s passing in my father .
# Target:		When I was young , I worked in my father ’s factory during vacations .
#
# Spanish:	Los padres , parientes y donantes al fondo misional general también ayudan .
# Translation:	Parents , and children , the missionary will also help you .
# Target:		Parents , families , friends , and donors to the General Missionary Fund may also assist .
#
# Spanish:	Les agradezco que se arrodillen reconociendo que no tienen todas las respuestas .
# Translation:	I thank you for you for all that you do n’t have the answers .
# Target:		I thank you for getting on your knees in recognition of the fact that you do n’t have all the answers .
#
# Spanish:	En medio de los arbustos , oyó voces que se acercaban hacia él .
# Translation:	In the midst of the voices of him , he heard him be moved .
# Target:		Through the bushes he could hear voices coming toward him .
#
# Spanish:	En menos de dos semanas se enteró de que estaba esperando un hijo .
# Translation:	In less weeks I learned two weeks that he was waiting for a son .
# Target:		Within two weeks she learned that she was expecting a child .
#
# Spanish:	Fue cuando seguí el mandamiento de las Escrituras de buscar a los pobres .
# Translation:	It was when I was the commandment to seek the poor .
# Target:		It came from following the scriptural command to seek out the poor .
#
# Spanish:	( Juan 11:40 ) ; y habiendo dicho esto clamó a gran voz :
# Translation:	( John 8:12 ; and he said this great voice cried out , no voice :
# Target:		And having said this , He cried out with a loud voice :
#
# Spanish:	El hermano Walter Krause falleció hace nueve años , a los 94 años .
# Translation:	Brother Walter Krause passed away last years ago , at age .
# Target:		Brother Walter Krause passed away nine years ago at the age of 94 .
#
# Spanish:	Hace unos años , fui en <unk> con un grupo de mujeres jóvenes .
# Translation:	A few years ago I was in a group of young women .
# Target:		Some years ago , I went <unk> with a group of young women .
#
# Spanish:	¿ Decimos y no hacemos , o con entusiasmo vivimos lo que predicamos ?
# Translation:	Will we say , and we do not know how we live ?
# Target:		Do we just talk the talk , or do we enthusiastically walk the walk ?
#
# Spanish:	pero sí nos ofrecen alguna idea sobre el carácter de Santiago y Juan .
# Translation:	But He will give us some idea about the character of James and John .
# Target:		However , we do get brief glimpses into the character of James and John .
#
# Spanish:	Muchas veces en la vida Él nos tiende la mano y nos invita :
# Translation:	Many times in Him in life will transform us from hand and invites us .
# Target:		Throughout various times of our lives , He holds out His hand and invites us :
#
# Spanish:	Gracias Coro del Tabernáculo , por ese dulce tributo al Salvador del mundo .
# Translation:	Of the Tabernacle Choir , for that tender mercies came to the Savior ’s world .
# Target:		Thank you , Tabernacle Choir , for that sweet tribute to the Savior of the world .
#
# Spanish:	Todavía sigo aprendiendo y mi comprensión del poder de la oración sigue aumentando .
# Translation:	I still remember and my understanding of the power of prayer continues to be blessed .
# Target:		I still continue to learn , and my understanding of the power of prayer still continues to grow .
#
# Spanish:	Mientras estaba allí , ella y Derek <unk> Cordon llegaron a ser buenos amigos .
# Translation:	While there , she was a lot of anxiety , she spent good friends .
# Target:		While there she became good friends with Derek <unk> Cordon .
#
# Spanish:	Se me llenaron los ojos de lágrimas al expresarle cuán agradecido estaba por él .
# Translation:	I was touched by tears of tears as I was grateful for him .
# Target:		Tears came as I expressed how grateful I was for him .
#
# Spanish:	Ninguna causa ni fuerza en el mundo entero puede detener la obra de Dios .
# Translation:	No cause or strength in the world can stop the work of God .
# Target:		No force in the entire world can stop the work of God .
#
# Spanish:	La validez misma de esta Iglesia se basa en la realidad de esa visión .
# Translation:	The same thing of this Church is based on the reality of that vision .
# Target:		On the question of its reality lies the very validity of this Church .
#
# Spanish:	Y ruego que siempre sigan siendo misioneros y que actúen como discípulos de Cristo .
# Translation:	And I pray that we will always follow the missionaries and act as disciples of Christ .
# Target:		And may you always continue to be missionaries and act like disciples of Christ .
#
# Spanish:	Al ser <unk> de este modo , desarrollamos paciencia y confianza en el Señor .
# Translation:	As we raise this way , we develop patience and trust in the Lord .
# Target:		Being temperate in this way , we develop patience and trust in the Lord .
#
# Spanish:	Véase Artículos de Fe 1:2 ; véanse también 2 Nefi 2:25 ; Moisés <unk> .
# Translation:	See Articles of Faith 1:10 ; see also 2 Nephi 2:25 ; Moses 6:65–68 .
# Target:		See Articles of Faith 1:2 ; see also 2 Nephi 2:25 ; Moses <unk> .
#
# Spanish:	Testifico que él posee y ejerce todas las llaves del sacerdocio en la Tierra .
# Translation:	I testify that he holds and exercises all keys in the earth .
# Target:		I witness that he holds and exercises all the keys of the priesthood on earth .
#
# Spanish:	Pedro respondió , diciendo que todos ellos , al caminar juntos , le oprimían .
# Translation:	Peter answered , saying that all , referring to the military , he was able to walk .
# Target:		Peter ’s answer was that all of them , walking together , were pressing against Him .
#
# Spanish:	“ Id por todo el mundo y predicad el evangelio a toda criatura ” .
# Translation:	“ Go ye therefore , and preach the gospel unto every creature . ”
# Target:		“ Go ye into all the world , and preach the gospel to every creature . ”
#
# Target:		He wants us to be safe and to be protected from the worldly influences all around us .
#
# Spanish:	¿ Les ayudaremos a ponerse esa armadura para que resistan los ardientes dardos del adversario ?
# Translation:	Will we help you get this armor to free the fiery darts of the adversary ?
# Target:		Will we help them put on that armor so they can withstand the fiery darts of the adversary ?
#
# Spanish:	Hay esperanza para los adictos , y esta esperanza llega mediante la expiación del Señor Jesucristo
# Translation:	There is hope for the addicted , and this hope comes through the Atonement of the Lord Jesus Christ .
# Target:		There is hope for the addicted , and this hope comes through the Atonement of the Lord Jesus Christ .
#
# Spanish:	Abby tuvo la impresión de que debía ofrecerse para ir a hablarles sobre ser madre .
# Translation:	Our father had the impression to go to meet again in being a mother .
# Target:		Parents were invited to send in an application if they wanted to come to school to teach the children about their jobs , and Abby felt impressed to apply to come and speak about motherhood .
#
# Spanish:	La noche de hogar se <unk> principalmente en la enseñanza del Evangelio y las actividades familiares .
# Translation:	The evening of home is being acquired in teaching and family activities .
# Target:		Home evenings focus primarily on gospel instruction and family activities .
#
# Spanish:	De todos modos , cada tanto se me ocurre que deberíamos ser un poco más <unk> .
# Translation:	Somehow , each of us is so much that we should be a little more than being .
# Target:		However , occasionally I think we should be a bit more competitive .
#
# Spanish:	La Iglesia de Jesucristo de los Santos de los Últimos Días nunca ha sido más fuerte .
# Translation:	The Church of Jesus Christ of Latter - day Saints has never been stronger .
# Target:		The Church of Jesus Christ of Latter - day Saints has never been stronger .
#
# Spanish:	Algunos miembros nos podrían ayudar a llevar personas y algunos scouts podrían empujar sillas de ruedas .
# Translation:	Some members could help us to achieve and some people with them .
# Target:		We could use some members to drive them and some Scouts to push wheelchairs .
#
# Spanish:	Si tomamos la decisión incorrecta , no tenemos que culpar a nadie sino a nosotros mismos .
# Translation:	If we make the choice , we have not to hide no one but we could not afford .
# Target:		If we make the wrong choice , we have no one to blame but ourselves .
#
# Spanish:	Él tiene todas las llaves para realizar con éxito el plan de Dios en la tierra .
# Translation:	He has all keys to do with success with God ’s plan in earth .
# Target:		He holds all the keys to successfully carry out God ’s work on the earth .
#
# Spanish:	Véase Predicad Mi Evangelio : Una guía para el servicio misional , 2004 , pág. 89 .
# Translation:	See Preach My Gospel : A Guide to Missionary Service ( 2004 ) , 89 .
# Target:		See Preach My Gospel : A Guide to Missionary Service ( 2004 ) , 87 .
#
# Spanish:	La Sociedad de Socorro siempre ha tenido la responsabilidad de participar en la obra de salvación .
# Translation:	Relief Society has always had the responsibility to participate in the work of salvation .
# Target:		It has always been a responsibility of Relief Society to participate in the work of salvation .
#
# Spanish:	Mis queridas hermanas , nada es más crucial para su vida eterna que su propia conversión .
# Translation:	My dear sisters , nothing crucial is crucial to your own conversion that your own conversion .
# Target:		My dear sisters , nothing is more crucial to your eternal life than your own conversion .
#
# Spanish:	Como no tenía esperanzas de ser rescatada , se <unk> contra el horror de su realidad .
# Translation:	As she was not sure she needed to be silent , she realized the reality of her .
# Target:		She had no hope of rescue , so she hardened herself to the horror of her reality .
#
# Spanish:	Como actividad , <unk> un escudo de HLJ en una cartulina y escriban sus ideas allí .
# Translation:	As a grudge rested of a stranger in a manger and put his ideas .
# Target:		For an activity , draw a CTR shield on a poster and write your ideas on it .
#
# Spanish:	Oré en busca de inspiración en cuanto a la forma que se pudiera cumplir ese deseo .
# Translation:	I prayed for inspiration regarding the way I could do to fulfill that desire .
# Target:		The inspiration came , and I said to Craig , “ Serve the Lord with all your heart .
#
# Spanish:	A los 38 años fue asesinado por un populacho de 150 hombres con la cara <unk> .
# Translation:	The 38 years was 38 to be judged by men with the face of the face .
# Target:		At the age of 38 , he was <unk> by a mob of 150 men with painted faces .
#
# Spanish:	¿ Cómo podemos librarnos de esa <unk> de problemas e incertidumbres para encontrar tranquilidad y felicidad ?
# Translation:	How can we bring this to pass that we can find and find happiness ?
# Target:		How can we free ourselves from this <unk> web of challenges and uncertainties to find peace of mind and happiness ?
#
# Spanish:	No , no es lo mismo que una entrevista personal cara a cara , pero casi .
# Translation:	No , it is not what a personal interview was to face , but almost .
# Target:		No , it is n’t the same as a personal , face - to - face interview . But it ’s close .
#
# Spanish:	Una de las formas más importantes de practicar la caridad es mediante el programa de maestras visitantes .
# Translation:	One of the most important ways to practice the program is through the program .
# Target:		One of the most important ways to practice charity is through visiting teaching .
#
# Spanish:	Conversación telefónica con el presidente Maxwell <unk> , Estaca <unk> , Nueva Zelanda , marzo de 2011 .
# Translation:	discussion with President Monson ’s Digest , Oct. 29 , 2011 , 2011 , 2011 .
# Target:		Phone conversation with President Maxwell <unk> , <unk> New Zealand Stake , Mar. 2011 .
#
# Spanish:	En su último discurso de la Conferencia General de abril de 2007 , el presidente Faust declaró :
# Translation:	In his last April ’s talk , the general conference , President Faust declared :
# Target:		In his last general conference address , in April of 2007 , President Faust declared :
#
# Spanish:	Recuerden que algunas de las necesidades más grandes pueden ser aquellas que estén justo frente a ustedes .
# Translation:	Remember that some of the greatest needs you to be those you are going to be .
# Target:		Remember that some of the greatest needs may be those right in front of you .
#
# Spanish:	Un Padre Celestial amoroso ha trazado nuestro curso y ha proporcionado una guía infalible : la obediencia .
# Translation:	A loving Heavenly Father has provided a course and has provided a willingness to lead : obedience .
# Target:		A loving Heavenly Father has plotted our course and provided an unfailing guide — even obedience .
#
# Spanish:	Uno debe considerar su llamamiento con la perspectiva de que está en la obra del Señor ” .
# Translation:	One must consider their calling with the Lord ’s perspective that is in the work of the Lord . ”
# Target:		He should think of his calling as though he were on the Lord ’s errand . ”
#
# Spanish:	sí , serán bendecidos mucho más que aquellos que se ven obligados a ser humildes … ” .
# Translation:	And they will be blessed that those who are humble themselves to be humble . ”
# Target:		“ Yea , they are much more blessed than they who are compelled to be humble . ”
#
# Spanish:	Es interesante notar que sus decisiones les permitieron el acceso a experiencias que podían fortalecer la fe .
# Translation:	It is interesting to note that their decisions would pay the experiences they could strengthen the faith .
# Target:		It is interesting to note that their choices allowed them access to potentially faith - building experiences .
#
# Spanish:	Sus anhelos secretos y sus lágrimas de súplica <unk> el corazón tanto del Padre como del Hijo .
# Translation:	His blood and his tears of his heart will be the Father ’s heart as the Son .
# Target:		Your secret yearnings and tearful pleadings will touch the heart of both the Father and the Son .
#
# Spanish:	De hecho , al parecer se les dificulta ver esas cosas que yo tanto admiro en ellos .
# Translation:	In fact , as we were often known these things I admire these things that I would be in them .
# Target:		In fact , they seem to have difficulty seeing those things that I so much admire in them .
#
# Spanish:	Nos <unk> con nuestra naturaleza divina al sentir y al dar el amor de nuestro Padre Celestial .
# Translation:	We woke up with our divine nature and give to love our Heavenly Father ’s love .
# Target:		We identify with our divine nature as we feel and give the love of our Father in Heaven .
#
# Spanish:	Aunque extrañamos a nuestros nietos , sabemos que viven , y sabemos que los veremos de nuevo .
# Translation:	Although we miss our grandchildren , we know that we know we know that we will see the new .
# Target:		Although we miss our grandchildren , we know they live , and we know we will see them again .
#
# Spanish:	Al esforzarse por ser dignos del Espíritu , reconocerán pensamientos y sentimientos que los inspirarán a ministrar .
# Translation:	As you strive to be worthy of the Spirit , you will recognize that the feelings will fill you .
# Target:		As you strive to be worthy of the Spirit , you will recognize thoughts and feelings prompting you to minister .
#
# Spanish:	Tengamos todos nosotros el valor de desafiar la opinión popular , la valentía de defender nuestros principios .
# Translation:	Let us be the worth of the popular , popular , the emotional , and the principles of our lives .
# Target:		Let us — all of us — have the courage to defy the consensus , the courage to stand for principle .
#
# Spanish:	Thomas S. Monson , “ Al rescate ” , Liahona , julio de 2001 , pág. 57 .
# Translation:	Thomas S. Monson , “ To the Rescue , ” Liahona and Ensign , May 2001 , 67 .
# Target:		Thomas S. Monson , “ To the Rescue , ” Liahona , July 2001 , 57 , 58 ; Ensign , May 2001 , 48 , 49 .
#
# Spanish:	Las dificultades mismas pueden ser la forma de fortalecer y , al final , obtener una fe inquebrantable .
# Translation:	The same difficulties can be the way of strengthen and gain a perfect faith .
# Target:		Trouble itself can be your way to strengthen and finally gain unshakable faith .
#
# Spanish:	“ Y también todos los que reciben este sacerdocio , a mí me reciben , dice el Señor ;
# Translation:	“ And all the priesthood which come unto me , I know me , ” says the Lord Himself .
# Target:		“ And also all they who receive this priesthood receive me , saith the Lord ;
#
# Spanish:	Los sentimientos en cuanto a nuestra Iglesia se producen tras la conversión a Jesucristo ; no la preceden .
# Translation:	The feelings of the Church will be built after our conversion . He will not remove the bird swiftly .
# Target:		Feelings about our Church follow conversion to Jesus Christ ; they do not precede it .
#
# Spanish:	Sus padres también habían orado para que la visita al templo proporcionara la ayuda que su hijo necesitaba .
# Translation:	His parents also had prayed for the visit the temple to the temple that their son needed .
# Target:		His parents also had prayed that this temple visit would provide the help their son needed .
#
# Spanish:	Al mismo tiempo , le testificó del amor incondicional , inflexible e imperecedero que ella sentía por él .
# Translation:	At the same time , I thanked the love of the mansion .
# Target:		In the same breath she testified of her own uncompromised , undying love for him as well .
#
# Spanish:	“ 40 Ways to Help Refugees in Your Community ” , 9 de septiembre de 2015 , mormonchannel.org .
# Translation:	“ 40 Ways to Help Refugees in Your Sins , ” 9 of 2015 , “ Come , O Thou Rock of Thy Name .
# Target:		“ 40 Ways to Help Refugees in Your Community , ” Sept. 9 , 2015 , mormonchannel.org .
#
# Spanish:	Los misioneros comparten por todo el mundo el plan que nuestro Padre tiene para nuestra felicidad y salvación .
# Translation:	Missionaries share with all the world the plan that our Father has for our happiness and salvation .
# Target:		Our Father ’s plan for our happiness and our salvation is shared by our missionaries throughout the world .
#
# Spanish:	La Primera Presidencia ha emitido el siguiente informe estadístico de la Iglesia al 31 de diciembre de 2015 .
# Translation:	The First Presidency has issued the following statistical report of the Church as a 2015 .
# Target:		The First Presidency has issued the following statistical report of the Church as of December 31 , 2015 .
#
# Spanish:	Sus tiernas misericordias llegarán a ser evidentes en nuestro corazón , en nuestra vida y en nuestra familia .
# Translation:	His tender mercies will become evident in our hearts , in our lives , and in our families .
# Target:		His tender mercies will become evident in our hearts , in our lives , and in our families .
#
# Spanish:	Las Escrituras nos enseñan : “ … todos pecaron y están destituidos de la gloria de Dios ” .
# Translation:	The scriptures teach us , “ All have sinned , and come short of the glory of God . ”
# Target:		The scriptures teach us , “ All have sinned , and come short of the glory of God . ”
#
# Spanish:	Con sincera emoción dijo : “ Mamá , acabo de tener la experiencia más increíble con Ashley ” .
# Translation:	With heartfelt emotion , “ Mom , I have been a most incredible experience with Ashley . ”
# Target:		With tender emotion she said , “ Mom , I just had the most incredible experience with Ashley . ”
#
# Spanish:	Casi puedo ver al Salvador mirando con un amor infinito el semblante de estos discípulos fieles y creyentes .
# Translation:	I can start to see the Savior as we look forward to the countenance of faithful disciples and believers .
# Target:		I can almost see the Savior , looking with infinite love into the faces of those faithful and believing disciples .
#
# Spanish:	El profeta Mormón describió una de las características clave del Salvador , la cual deben emular Sus discípulos .
# Translation:	The prophet Mormon described a key characteristics of the Savior , which must emulate His disciples .
# Target:		The prophet Mormon outlined one of the key characteristics of the Savior and which is to be emulated by His disciples .
#
# Spanish:	Les dije : “ ¿ Hace cuánto que no van al templo a presenciar un sellamiento ? ” .
# Translation:	I said , “ Have I not much about how I will not work ? ”
# Target:		I said , “ How long has it been since you have been to the temple and witnessed a temple sealing ? ”
#
# Spanish:	<unk> : <unk> que fluye en sentido contrario a otra , causando una violenta agitación en el mar .
# Translation:	Let ’s examine your own pace to make another bit of a manger , causing a stranger .
# Target:		<unk> : “ a tide that opposes another or other <unk> , causing a violent <unk> in the sea ” ( <unk> ) .
#
# Spanish:	¡ Se supone que son los padres , no los hijos , quienes deben proteger a su familia ! .
# Translation:	It is the parents who are parents , who must protect them into your family !
# Target:		Fathers , not children , are supposed to protect their families !
#
# Spanish:	Véase D. y C. <unk> ; véase también Guía para el Estudio de las Escrituras , “ David ” .
# Translation:	See Doctrine and Covenants 35:2 ; see also Guide to the Scriptures , “ David . ”
# Target:		See Doctrine and Covenants <unk> ; see also Bible Dictionary , “ David . ”
#
# Spanish:	En el diccionario bíblico en inglés dice que un convenio es un contrato hecho entre Dios y el hombre .
# Translation:	In the Bible Dictionary , He says that a covenant is a man and man .
# Target:		The Bible Dictionary tells us that a covenant is a contract made between God and man .
#
# Spanish:	El testimonio es importante y necesario pero no suficiente para proporcionar la fortaleza espiritual y la protección que necesitamos .
# Translation:	The testimony is important and necessary to provide for spiritual strength and protection for the spiritual strength we need .
# Target:		Testimony is important and necessary but not sufficient to provide the spiritual strength and protection we need .
#
# Spanish:	A. <unk> Tuttle , “ The Role of Fathers ” , Ensign , enero de 1974 , pág. 67 .
# Translation:	Alfred Tennyson , “ The Role of Youth , ” Ensign , Nov. 1974 , 67 .
# Target:		A. <unk> Tuttle , “ The Role of Fathers , ” Ensign , Jan. 1974 , 67 .
#
# Spanish:	En esta religión no nos preocupamos solo de nosotros mismos , sino que también se nos llama a servir .
# Translation:	In this religion we do not need to be just one of ourselves but also called us to serve .
# Target:		This religion is not concerned only with self ; rather , we are all called to serve .
#
# Spanish:	Acepten más profundamente a Su amor , Su misericordia , Su gracia y los potentes dones de Su expiación .
# Translation:	Accept His most deeply , His mercy , mercy , and plan of His Atonement .
# Target:		Embrace more deeply His love , His mercy and grace , and the powerful gifts of His Atonement .
#
# Spanish:	La prueba para cada uno de nosotros es cómo respondemos a lo que escuchamos y a lo que sentimos .
# Translation:	The test for each of us is how we respond to what we hear and know .
# Target:		The test for each of us is how we respond to what we hear and what we feel .
#
# Spanish:	Lema de las Mujeres Jóvenes , en Mujeres Jóvenes , Progreso Personal , librito , 2009 , pág. 3 .
# Translation:	October 2009 , Young Women Personal Progress ( booklet , 2009 ) , 3 .
# Target:		“ Young Women Theme , ” in Young Women Personal Progress ( booklet , 2009 ) , 3 .
#
# Spanish:	Otros quizás no sientan la necesidad de mejorar , de modo que esas ayudas pueden ser invisibles para ustedes .
# Translation:	Others may not feel the need of our own , which can be performed for you .
# Target:		For others you may not feel the need for growth , so these helps may be invisible to you .
#
# Spanish:	Puesto que no somos perfectos y debido a que nos equivocamos , necesitamos ayuda para regresar a Su presencia .
# Translation:	Because we are not perfect and because we need to return , we need to return to His presence .
# Target:		Because we are not perfect and because we make mistakes , we need help in returning to His presence .
#
# Spanish:	Luego la guardó en el bolsillo de su saco y le dijo que él se encargaría de su petición .
# Translation:	Then I then kept the pocket of his pocket and told him that he would be understood .
# Target:		Then he put it in his suit pocket and told Brother Zayas that he would take care of their request .
#
# Spanish:	George Q. Cannon , “ Our <unk> and Present <unk> , ” <unk> , octubre <unk> , pág. <unk> .
# Translation:	George Q. Cannon , “ Our Hearts and Moving Forward , ” Improvement Era , Oct. 1981 , 46–47 .
# Target:		George Q. Cannon , “ Our <unk> - existence and Present <unk> , ” <unk> , Oct. <unk> , <unk> .
#
# Spanish:	Cuando nuestro corazón está lleno de orgullo , cometemos un grave pecado , porque <unk> los dos grandes mandamientos .
# Translation:	When our hearts are filled with pride , we make a serious sin , because we are struggling with commandments .
# Target:		When our hearts are filled with pride , we commit a grave sin , for we violate the two great commandments .
#
